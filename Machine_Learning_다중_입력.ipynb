# %% [markdown]
# <a href="https://colab.research.google.com/github/Rlackdals981010/NLP_STUDY_WITH_DL/blob/main/Machine_Learning_%EB%8B%A4%EC%A4%91_%EC%9E%85%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#독립 변수 x가 한 model에 2개 이상인
#다중 선형회귀
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

# %%
## 중간 고사, 기말 고사, 가산점 점수
X = np.array([[70,85,11], [71,89,18], [50,80,20], [99,20,10], [50,10,10]])
y = np.array([73, 82 ,72, 57, 34]) # 최종 성적

model = Sequential()
model.add(Dense(1, input_dim=3, activation='linear'))

sgd = optimizers.SGD(learning_rate=0.0001)

model.compile(optimizer=sgd, loss = 'mse', metrics = ['mse'])
model.fit(X,y,epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 451ms/step - loss: 1069.7788 - mse: 1069.7788
# Epoch 2/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 623.3765 - mse: 623.3765
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 379.9778 - mse: 379.9778
# Epoch 4/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 246.2166 - mse: 246.2166
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 171.9972 - mse: 171.9972
# Epoch 6/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 130.3275 - mse: 130.3275
# Epoch 7/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 106.5901 - mse: 106.5901
# Epoch 8/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 92.8214 - mse: 92.8214
# Epoch 9/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 84.6512 - mse: 84.6512
# Epoch 10/2000
# ...

# %%
print(model.predict(X))
# Out:
# 1/1 [==============================] - 0s 78ms/step
# [[72.94679 ]
#  [81.97151 ]
#  [72.08441 ]
#  [57.113678]
#  [33.805824]]

# %%
X_test = np.array([[20,99,10], [40,50,20]])
print(model.predict(X_test))
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[57.93048 ]
#  [56.042393]]

# %%
#다중 로지스틱 회귀
# 두 개의 입력의 합이 2이상이면 출력값가 1이 되고 두 개의 입력의 합이 2미만인 경우에만 출력값이 0이 되는 로직

X = np.array([[0, 0], [0, 1], [1, 0], [0, 2], [1, 1], [2, 0]])
y = np.array([0, 0, 0, 1, 1, 1])

model=Sequential()
model.add(Dense(1,input_dim=2,activation='sigmoid'))
model.compile(optimizer='sgd',loss='binary_crossentropy',metrics=['binary_accuracy'])

model.fit(X,y,epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 483ms/step - loss: 0.6070 - binary_accuracy: 0.6667
# Epoch 2/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6068 - binary_accuracy: 0.6667
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6065 - binary_accuracy: 0.6667
# Epoch 4/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6063 - binary_accuracy: 0.6667
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6060 - binary_accuracy: 0.6667
# Epoch 6/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6058 - binary_accuracy: 0.6667
# Epoch 7/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6056 - binary_accuracy: 0.6667
# Epoch 8/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6053 - binary_accuracy: 0.6667
# Epoch 9/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6051 - binary_accuracy: 0.6667
# ...

# %%
print(model.predict(X))
# Out:
# 1/1 [==============================] - 0s 118ms/step
# [[0.16035157]
#  [0.4462891 ]
#  [0.44403252]
#  [0.77281284]
#  [0.77120477]
#  [0.7695887 ]]
